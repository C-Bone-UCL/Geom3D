# %%
import os
os.chdir('/rds/general/user/ma11115/home/Geom3D/Geom3D/')
#os.chdir('C:/Users/ma11115/OneDrive - Imperial College London/Geom3d/Geom3D/')

# %%
from geom3d.test_train import *
import torch
import copy
chkpt_path = os.getcwd()+"/training/SchNet_target_80K_TEST_5e4lr/epoch=91-val_loss=0.56-other_metric=0.00.ckpt"
config_dir = os.getcwd()+"/training/SchNet_target_80K_TEST_5e4lr/"
torch.use_deterministic_algorithms(False)
os.environ['CUDA_LAUNCH_BLOCKING'] = str(1)
def plot_training_results(chkpt_path, config_dir):
    config = read_config(config_dir)
    np.random.seed(config["seed"])
    torch.cuda.manual_seed_all(config["seed"])
    torch.manual_seed(config["seed"])
    config["device"] = "cuda:0" if torch.cuda.is_available() else "cpu"
    pymodel = Pymodel.load_from_checkpoint(chkpt_path)#,map_location={"cuda:0":"cpu"})
    pymodel.freeze()
    
    #pymodel.to('cpu')

    #config["device"] = "cpu" #"cuda" if torch.cuda.is_available() else "cpu"
    
    np.random.seed(config["seed"])
    torch.cuda.manual_seed_all(config["seed"])
    dataset = load_data(config)
    print('y_pred', pymodel(dataset[0].to(config["device"])))
    print('y_true', dataset[0].y)
    pymode_cpu = copy.deepcopy(pymodel).to('cpu')
    print('y_pred_cpu', pymode_cpu(dataset[0].to('cpu')))
    

    train_loader, val_loader, test_loader = train_val_test_split(
        dataset, config=config
    )
    # %matplotlib inline
    import matplotlib.pyplot as plt
    print("pymodel device", pymodel.device)
    fig, axis = plt.subplots(1,3, figsize=(15,5))
    for id,loader in enumerate([train_loader, val_loader, test_loader]):
        axis[id].set_ylabel('y_pred')
        axis[id].set_xlabel('y_true')
        
        for x in loader:
            with torch.no_grad():
                Y_pred = pymodel(x.to(config["device"]))
            break
        axis[id].scatter( x.y.to('cpu'),Y_pred.to('cpu').detach(),)
        axis[id].plot(x.y.to('cpu'),x.y.to('cpu'))
        axis[id].set_title(['train set', 'validation set', 'test set'][id])
    plt.show()
    return train_loader,dataset
train_loader,dataset = plot_training_results(chkpt_path, config_dir)
# Out:
# config loaded from /rds/general/user/ma11115/home/Geom3D/Geom3D/training/SchNet_target_80K_TEST_5e4lr/
# y_pred tensor([[-9.0663]], device='cuda:0')
# y_true tensor(-8.7690, device='cuda:0')
# y_pred_cpu tensor([[-9.4689]])
# train_idx:  [47044 44295 74783 ... 77925 18116 14762]
# valid_idx:  [39698 66692  7139 ... 52300 56176  3346]
# test_idx:  [61260 28261 49228 ... 76820   860 15795]
# pymodel device cuda:0

# %%
# %run src/geom3d/test_train.py --config_dir /training/SchNet_target_80K_TEST_5e4lr
# Out:
# config loaded from /rds/general/user/ma11115/home/Geom3D/Geom3D/training/SchNet_target_80K_TEST_5e4lr
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~/Geom3D/Geom3D/src/geom3d/test_train.py:277
#     275 args = argparser.parse_args()
#     276 config_dir = root + args.config_dir
# --> 277 main(config_dir=config_dir)
#
# File ~/Geom3D/Geom3D/src/geom3d/test_train.py:35, in main(config_dir)
#      31 torch.cuda.manual_seed_all(config["seed"])
#      32 config["device"] = (
#      33     "cuda" if torch.cuda.is_available() else torch.device("cpu")
#      34 )
# ---> 35 dataset = load_data(config)
#      36 train_loader, val_loader, test_loader = train_val_test_split(
#      37     dataset, config=config
#      38 )
#      39 model_config = config["model"]
#
# File ~/Geom3D/Geom3D/src/geom3d/test_train.py:94, in load_data(config)
#      92 if config["load_dataset"]:
#      93     if os.path.exists(config["dataset_path"]):
# ---> 94         dataset = torch.load(config["dataset_path"])
#      95         return dataset
#      96     else:
#
# File ~/anaconda3/envs/Geom3D/lib/python3.11/site-packages/torch/serialization.py:1014, in load(f, map_location, pickle_module, weights_only, mmap, **pickle_load_args)
#    1012             except RuntimeError as e:
#    1013                 raise pickle.UnpicklingError(UNSAFE_MESSAGE + str(e)) from None
# -> 1014         return _load(opened_zipfile,
#    1015                      map_location,
#    1016                      pickle_module,
#    1017                      overall_storage=overall_storage,
#    1018                      **pickle_load_args)
#    1019 if mmap:
#    1020     raise RuntimeError("mmap can only be used with files saved with ",
#    1021                        "`torch.save(_use_new_zipfile_serialization=True), "
#    1022                        "please torch.save your checkpoint with this option in order to use mmap.")
#
# File ~/anaconda3/envs/Geom3D/lib/python3.11/site-packages/torch/serialization.py:1422, in _load(zip_file, map_location, pickle_module, pickle_file, overall_storage, **pickle_load_args)
#    1420 unpickler = UnpicklerWrapper(data_file, **pickle_load_args)
#    1421 unpickler.persistent_load = persistent_load
# -> 1422 result = unpickler.load()
#    1424 torch._utils._validate_loaded_sparse_tensors()
#    1425 torch._C._log_api_usage_metadata(
#    1426     "torch.load.metadata", {"serialization_id": zip_file.serialization_id()}
#    1427 )
#
# File ~/anaconda3/envs/Geom3D/lib/python3.11/site-packages/torch/serialization.py:1392, in _load.<locals>.persistent_load(saved_id)
#    1390 else:
#    1391     nbytes = numel * torch._utils._element_size(dtype)
# -> 1392     typed_storage = load_tensor(dtype, nbytes, key, _maybe_decode_ascii(location))
#    1394 return typed_storage
#
# File ~/anaconda3/envs/Geom3D/lib/python3.11/site-packages/torch/serialization.py:1357, in _load.<locals>.load_tensor(dtype, numel, key, location)
#    1355     storage = overall_storage[storage_offset:storage_offset + numel]
#    1356 else:
# -> 1357     storage = zip_file.get_storage_from_record(name, numel, torch.UntypedStorage)._typed_storage()._untyped_storage
#    1358 # swap here if byteswapping is needed
#    1359 if byteorderdata is not None:
#
# KeyboardInterrupt:

# %%
os.chdir('/rds/general/user/ma11115/home/Geom3D/Geom3D/')

# %run src/geom3d/fragencoding.py --config_dir /training/SchNet_target_80K_TEST_5e4lr
# Out:
# config loaded from /rds/general/user/ma11115/home/Geom3D/Geom3D/training/SchNet_target_80K_TEST_5e4lr
# dataset not found
# wandb: WARNING Source type is set to 'repo' but some required information is missing from the environment. A job will not be created from this run. See https://docs.wandb.ai/guides/launch/create-job
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~/Geom3D/Geom3D/src/geom3d/fragencoding.py:305
#     303 args = argparser.parse_args()
#     304 config_dir = root + args.config_dir
# --> 305 main(config_dir=config_dir)
#
# File ~/Geom3D/Geom3D/src/geom3d/fragencoding.py:37, in main(config_dir)
#      32 config["device"] = (
#      33     "cuda" if torch.cuda.is_available() else torch.device("cpu")
#      34 )
#      35 #model_config = config["model"]
# ---> 37 dataset = load_data(config)
#      38 train_loader, val_loader, test_loader = train_val_test_split(
#      39     dataset, config=config
#      40 )
#      41 wandb.login()
#
# File ~/Geom3D/Geom3D/src/geom3d/fragencoding.py:148, in load_data(config)
#     146 pymodel.to(config["device"])
#     147 model = pymodel.molecule_3D_repr
# --> 148 dataset = generate_dataset_frag(
#     149     df_total,
#     150     model,
#     151     db,
#     152     number_of_molecules=config["num_molecules"],
#     153     number_of_fragement=config["number_of_fragement"],
#     154 )
#     155 if config["save_dataset"]:
#     156     name = config["name"] + "_frag_" + str(config["number_of_fragement"])
#
# File ~/Geom3D/Geom3D/src/geom3d/fragencoding.py:180, in generate_dataset_frag(df_total, model, db, number_of_molecules, number_of_fragement)
#     178 data_list = []
#     179 for i in molecule_index:
# --> 180     moldata = fragment_based_encoding(
#     181         df_total["InChIKey"][i], db, model, number_of_fragement
#     182     )
#     183     if moldata is not None:
#     184         data_list.append(moldata)
#
# File ~/Geom3D/Geom3D/src/geom3d/fragencoding.py:192, in fragment_based_encoding(InChIKey, db_poly, model, number_of_fragement)
#     188 def fragment_based_encoding(InChIKey, db_poly, model, number_of_fragement=6):
#     189     device = (
#     190         "cuda" if torch.cuda.is_available() else torch.device("cpu")
#     191     )
# --> 192     polymer = db_poly.get({"InChIKey": InChIKey})
#     193     frags = []
#     194     dat_list = list(polymer.get_atomic_positions())
#
# File ~/anaconda3/envs/Geom3D/lib/python3.11/site-packages/stk/_internal/databases/mongo_db/constructed_molecule.py:611, in ConstructedMoleculeMongoDb.get(self, key)
#     608 def get(self, key):
#     609     # lru_cache requires that the parameters to the cached function
#     610     # are hashable objects.
# --> 611     return self._get(HashableDict(key))
#
# File ~/anaconda3/envs/Geom3D/lib/python3.11/site-packages/stk/_internal/databases/mongo_db/constructed_molecule.py:654, in ConstructedMoleculeMongoDb._get(self, key)
#     643 if position_matrix is None:
#     644     raise KeyError(
#     645         "No position matrix found in the database with a key "
#     646         f"of: {key}"
#     647     )
#     649 return self._dejsonizer.from_json(
#     650     json={
#     651         "molecule": molecule_json,
#     652         "constructedMolecule": constructed_molecule_json,
#     653         "matrix": position_matrix,
# --> 654         "buildingBlocks": tuple(
#     655             map(
#     656                 self._get_building_block,
#     657                 constructed_molecule_json["BB"],
#     658             )
#     659         ),
#     660     },
#     661 )
#
# File ~/anaconda3/envs/Geom3D/lib/python3.11/site-packages/stk/_internal/databases/mongo_db/constructed_molecule.py:665, in ConstructedMoleculeMongoDb._get_building_block(self, key)
#     663 def _get_building_block(self, key):
#     664     return {
# --> 665         "molecule": self._molecules.find_one(key),
#     666         "matrix": self._building_block_position_matrices.find_one(key),
#     667     }
#
# File ~/anaconda3/envs/Geom3D/lib/python3.11/site-packages/pymongo/collection.py:1506, in Collection.find_one(self, filter, *args, **kwargs)
#    1504     filter = {"_id": filter}
#    1505 cursor = self.find(filter, *args, **kwargs)
# -> 1506 for result in cursor.limit(-1):
#    1507     return result
#    1508 return None
#
# File ~/anaconda3/envs/Geom3D/lib/python3.11/site-packages/pymongo/cursor.py:1264, in Cursor.next(self)
#    1262 if self.__empty:
#    1263     raise StopIteration
# -> 1264 if len(self.__data) or self._refresh():
#    1265     return self.__data.popleft()
#    1266 else:
#
# File ~/anaconda3/envs/Geom3D/lib/python3.11/site-packages/pymongo/cursor.py:1181, in Cursor._refresh(self)
#    1159         raise InvalidOperation(
#    1160             "Passing a 'hint' is required when using the min/max query"
#    1161             " option to ensure the query utilizes the correct index"
#    1162         )
#    1163     q = self._query_class(
#    1164         self.__query_flags,
#    1165         self.__collection.database.name,
#    (...)
#    1179         self.__exhaust,
#    1180     )
# -> 1181     self.__send_message(q)
#    1182 elif self.__id:  # Get More
#    1183     if self.__limit:
#
# File ~/anaconda3/envs/Geom3D/lib/python3.11/site-packages/pymongo/cursor.py:1060, in Cursor.__send_message(self, operation)
#    1057     raise InvalidOperation("exhaust cursors do not support auto encryption")
#    1059 try:
# -> 1060     response = client._run_operation(
#    1061         operation, self._unpack_response, address=self.__address
#    1062     )
#    1063 except OperationFailure as exc:
#    1064     if exc.code in _CURSOR_CLOSED_ERRORS or self.__exhaust:
#    1065         # Don't send killCursors because the cursor is already closed.
#
# File ~/anaconda3/envs/Geom3D/lib/python3.11/site-packages/pymongo/_csot.py:107, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     105         with _TimeoutContext(timeout):
#     106             return func(self, *args, **kwargs)
# --> 107 return func(self, *args, **kwargs)
#
# File ~/anaconda3/envs/Geom3D/lib/python3.11/site-packages/pymongo/mongo_client.py:1394, in MongoClient._run_operation(self, operation, unpack_res, address)
#    1389     operation.reset()  # Reset op in case of retry.
#    1390     return server.run_operation(
#    1391         conn, operation, read_preference, self._event_listeners, unpack_res
#    1392     )
# -> 1394 return self._retryable_read(
#    1395     _cmd,
#    1396     operation.read_preference,
#    1397     operation.session,
#    1398     address=address,
#    1399     retryable=isinstance(operation, message._Query),
#    1400 )
#
# File ~/anaconda3/envs/Geom3D/lib/python3.11/site-packages/pymongo/mongo_client.py:1492, in MongoClient._retryable_read(self, func, read_pref, session, address, retryable)
#    1487 # Ensure that the client supports retrying on reads and there is no session in
#    1488 # transaction, otherwise, we will not support retry behavior for this call.
#    1489 retryable = bool(
#    1490     retryable and self.options.retry_reads and not (session and session.in_transaction)
#    1491 )
# -> 1492 return self._retry_internal(
#    1493     func,
#    1494     session,
#    1495     None,
#    1496     is_read=True,
#    1497     address=address,
#    1498     read_pref=read_pref,
#    1499     retryable=retryable,
#    1500 )
#
# File ~/anaconda3/envs/Geom3D/lib/python3.11/site-packages/pymongo/_csot.py:107, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     105         with _TimeoutContext(timeout):
#     106             return func(self, *args, **kwargs)
# --> 107 return func(self, *args, **kwargs)
#
# File ~/anaconda3/envs/Geom3D/lib/python3.11/site-packages/pymongo/mongo_client.py:1462, in MongoClient._retry_internal(self, func, session, bulk, is_read, address, read_pref, retryable)
#    1428 @_csot.apply
#    1429 def _retry_internal(
#    1430     self,
#    (...)
#    1437     retryable: bool = False,
#    1438 ) -> T:
#    1439     """Internal retryable helper for all client transactions.
#    1440
#    1441     :Parameters:
#    (...)
#    1451       Output of the calling func()
#    1452     """
#    1453     return _ClientConnectionRetryable(
#    1454         mongo_client=self,
#    1455         func=func,
#    1456         bulk=bulk,
#    1457         is_read=is_read,
#    1458         session=session,
#    1459         read_pref=read_pref,
#    1460         address=address,
#    1461         retryable=retryable,
# -> 1462     ).run()
#
# File ~/anaconda3/envs/Geom3D/lib/python3.11/site-packages/pymongo/mongo_client.py:2315, in _ClientConnectionRetryable.run(self)
#    2313 self._check_last_error(check_csot=True)
#    2314 try:
# -> 2315     return self._read() if self._is_read else self._write()
#    2316 except ServerSelectionTimeoutError:
#    2317     # The application may think the write was never attempted
#    2318     # if we raise ServerSelectionTimeoutError on the retry
#    2319     # attempt. Raise the original exception instead.
#    2320     self._check_last_error()
#
# File ~/anaconda3/envs/Geom3D/lib/python3.11/site-packages/pymongo/mongo_client.py:2444, in _ClientConnectionRetryable._read(self)
#    2442 if self._retrying and not self._retryable:
#    2443     self._check_last_error()
# -> 2444 return self._func(self._session, self._server, conn, read_pref)
#
# File ~/anaconda3/envs/Geom3D/lib/python3.11/site-packages/pymongo/mongo_client.py:1390, in MongoClient._run_operation.<locals>._cmd(_session, server, conn, read_preference)
#    1383 def _cmd(
#    1384     _session: Optional[ClientSession],
#    1385     server: Server,
#    1386     conn: Connection,
#    1387     read_preference: _ServerMode,
#    1388 ) -> Response:
#    1389     operation.reset()  # Reset op in case of retry.
# -> 1390     return server.run_operation(
#    1391         conn, operation, read_preference, self._event_listeners, unpack_res
#    1392     )
#
# File ~/anaconda3/envs/Geom3D/lib/python3.11/site-packages/pymongo/helpers.py:322, in _handle_reauth.<locals>.inner(*args, **kwargs)
#     319 from pymongo.pool import Connection
#     321 try:
# --> 322     return func(*args, **kwargs)
#     323 except OperationFailure as exc:
#     324     if no_reauth:
#
# File ~/anaconda3/envs/Geom3D/lib/python3.11/site-packages/pymongo/server.py:148, in Server.run_operation(self, conn, operation, read_preference, listeners, unpack_res)
#     146 else:
#     147     conn.send_message(data, max_doc_size)
# --> 148     reply = conn.receive_message(request_id)
#     150 # Unpack and check for command errors.
#     151 if use_cmd:
#
# File ~/anaconda3/envs/Geom3D/lib/python3.11/site-packages/pymongo/pool.py:1022, in Connection.receive_message(self, request_id)
#    1020     return receive_message(self, request_id, self.max_message_size)
#    1021 except BaseException as error:
# -> 1022     self._raise_connection_failure(error)
#
# File ~/anaconda3/envs/Geom3D/lib/python3.11/site-packages/pymongo/pool.py:1020, in Connection.receive_message(self, request_id)
#    1015 """Receive a raw BSON message or raise ConnectionFailure.
#    1016
#    1017 If any exception is raised, the socket is closed.
#    1018 """
#    1019 try:
# -> 1020     return receive_message(self, request_id, self.max_message_size)
#    1021 except BaseException as error:
#    1022     self._raise_connection_failure(error)
#
# File ~/anaconda3/envs/Geom3D/lib/python3.11/site-packages/pymongo/network.py:257, in receive_message(conn, request_id, max_message_size)
#     255         deadline = None
#     256 # Ignore the response's request id.
# --> 257 length, _, response_to, op_code = _UNPACK_HEADER(_receive_data_on_socket(conn, 16, deadline))
#     258 # No request_id for exhaust cursor "getMore".
#     259 if request_id is not None:
#
# File ~/anaconda3/envs/Geom3D/lib/python3.11/site-packages/pymongo/network.py:340, in _receive_data_on_socket(conn, length, deadline)
#     338     if _csot.get_timeout() and deadline is not None:
#     339         conn.set_conn_timeout(max(deadline - time.monotonic(), 0))
# --> 340     chunk_length = conn.conn.recv_into(mv[bytes_read:])
#     341 except BLOCKING_IO_ERRORS:
#     342     raise socket.timeout("timed out") from None
#
# KeyboardInterrupt:

# %%
os.getcwd()
